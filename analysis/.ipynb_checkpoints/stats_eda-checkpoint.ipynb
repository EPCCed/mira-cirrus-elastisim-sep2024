# %%
import pandas as pd
import seaborn as sns

# %%
df_sep24 = pd.read_csv('all_stats_emissions_meanCI.csv')

# %%
sns.scatterplot(data=df_sep24, x='usageFraction', y='medianWait')
# Out:
# <Axes: xlabel='usageFraction', ylabel='medianWait'>

# %%
sns.scatterplot(data=df_sep24, x='usageFraction', y='emissionsIdle')
# Out:
# <Axes: xlabel='usageFraction', ylabel='emissionsIdle'>

# %%
sns.scatterplot(data=df_sep24, x='maxWait', y='medianWait')
# Out:
# <Axes: xlabel='maxWait', ylabel='medianWait'>
