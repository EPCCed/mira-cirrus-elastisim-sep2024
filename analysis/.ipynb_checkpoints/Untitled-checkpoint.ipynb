# %%
import pandas as pd
import seaborn as sns

# %%
df_sep24 = pd.read_csv('all_stats_emissions.csv')
df_sep24 = df_sep24.set_index('Unnamed: 0').T
df_sep24 = df_sep24.rename(columns={'Unnamed: 0': 'Dataset'})
df_sep24.head()
# Out:
# Unnamed: 0                    nJobStart  minLoad  maxLoad  medianLoad  \
# Measured                        45814.0      0.0  12924.0      8254.0
# Cirrus (Rigid: R)               40375.0    756.0  13248.0      8928.0
# Cirrus (Moldable: M)            40375.0    756.0  13248.0      9550.0
# Cirrus (M) + 10% ARCHER2 (R)    41528.0    770.0  13248.0     10631.0
# Cirrus (M) + 20% ARCHER2 (R)    42667.0   1776.0  13248.0     12599.0
#
# Unnamed: 0                    meanLoad  usageIncluded  usageExcluded  \
# Measured                        8378.0    5711012.314    2337663.841
# Cirrus (Rigid: R)               8761.0    5597553.146    2451071.526
# Cirrus (Moldable: M)            8874.0    5670106.381    2378396.381
# Cirrus (M) + 10% ARCHER2 (R)    9610.0    6140301.177    2709572.407
# Cirrus (M) + 20% ARCHER2 (R)   10362.0    6620546.305    3027951.533
#
# Unnamed: 0                    usageFraction  residualWork  minWait  \
# ...
